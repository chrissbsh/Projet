# %% [markdown]
# ## Explication type (1-1)

# %%
from gurobipy import *

# Données du problème
data = {
    'A': 32,
    'B': 0,
    'C': -28,
    'D': 36,
    'E': 48,
    'F': -35,
    'G': -42
}

# Identification des ensembles Pros et Cons
pros = [k for k, v in data.items() if v > 0]  # Ensemble Pros(x,y)
cons = [k for k, v in data.items() if v < 0]  # Ensemble Cons(x,y)

print(f"Pros: {pros}")
print(f"Cons: {cons}")

# Calcul des Trade-offs (1-1) valides
valid_pairs = []
for p in pros:
    for q in cons:
        if data[p] + data[q] > 0:
            valid_pairs.append((p, q))

print(f"Nombre de paires valides identifiées : {len(valid_pairs)}")

# Modélisation avec Gurobi

# Instanciation du modèle
m = Model("Explication_TradeOff_1_1")

# Création des variables binaires c[(p,q)]
# c = 1 si la paire est choisie, 0 sinon
c = {}
for p, q in valid_pairs:
    c[(p, q)] = m.addVar(vtype=GRB.BINARY, name=f"c_{p}_{q}")

# Mise à jour du modèle
m.update()

# Ajout des contraintes

# Contrainte 1 : Tout élément de Cons doit être couvert exactement une fois
# Somme(c_pq) = 1 pour chaque q dans Cons
for q in cons:
    # On utilise quicksum pour sommer efficacement les variables Gurobi concernées
    m.addConstr(quicksum(c[(p, q)] for p in pros if (p, q) in valid_pairs) == 1, name=f"Cover_{q}")

# Contrainte 2 : Tout élément de Pros est utilisé au maximum une fois
# Les trade-offs doivent être disjoints
for p in pros:
    m.addConstr(quicksum(c[(p, q)] for q in cons if (p, q) in valid_pairs) <= 1, name=f"Unique_{p}")

# Fonction Objectif
# Ici on cherche juste la faisabilité, on peut minimiser 0
m.setObjective(0, GRB.MINIMIZE)

# Paramétrage (mode silencieux)
m.params.outputflag = 0

# Résolution du PL
m.optimize()

# --- 4. Analyse des résultats ---
if m.status == GRB.OPTIMAL:
    print("\nSolution Optimale Trouvée (Explication Valide) :")
    explanation = []
    for p, q in valid_pairs:
        # On vérifie si la variable est à 1 (avec une petite tolérance pour les flottants)
        if c[(p, q)].x > 0.5:
            explanation.append((p,q))
            net_val = data[p] + data[q]
            print(f" - Trade-off ({p},{q})")
    
    # Vérification
    expected = {('A', 'C'), ('D', 'F'), ('E', 'G')}
    is_same = set(explanation) == expected

elif m.status == GRB.INFEASIBLE:
    print("\nModèle Infeasible : Il n'existe pas d'explication de type (1-1).")
    # Certificat de non-existence
# Out:
# Pros: ['A', 'D', 'E']
# Cons: ['C', 'F', 'G']
# Nombre de paires valides identifiées : 6
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2755100
# Academic license 2755100 - for non-commercial use only - registered to na___@student-cs.fr
#
# Solution Optimale Trouvée (Explication Valide) :
#  - Trade-off (A,C)
#  - Trade-off (D,F)
#  - Trade-off (E,G)

# %% [markdown]
# ## Explication type (1-m)

# %%
from gurobipy import *

# DONNÉES DU PROBLÈME
weights = {'A': 8, 'B': 7, 'C': 7, 'D': 6, 'E': 6, 'F': 5, 'G': 6}

# Notes des candidats u et v
notes_u = {'A': 72, 'B': 66, 'C': 75, 'D': 85, 'E': 88, 'F': 66, 'G': 93}
notes_v = {'A': 71, 'B': 73, 'C': 63, 'D': 92, 'E': 76, 'F': 79, 'G': 93}

# Calcul des contributions (deltas)
deltas = {}
for k in weights:
    deltas[k] = weights[k] * (notes_u[k] - notes_v[k])

pros = [k for k, v in deltas.items() if v > 0]
cons = [k for k, v in deltas.items() if v < 0]

print(f"Arguments Pour (Pros) : {pros}")
print(f"Arguments Contre (Cons) : {cons}")

# MODÉLISATION GUROBI
m = Model("Explication_1_m")

# Variables de décision UNIQUEMENT x
# x[p, c] = 1 si l'argument Pro 'p' couvre l'argument Con 'c'
x = m.addVars(pros, cons, vtype=GRB.BINARY, name="x")

m.update()

# CONTRAINTES

# A. Couverture complète : Chaque Con doit être couvert par exactement un Pro
for c in cons:
    m.addConstr(quicksum(x[p, c] for p in pros) == 1, name=f"Cover_{c}")

# B. Validité du Trade-off
# Formule : Delta_p + Somme(Delta_c * x_pc) >= epsilon
# Si p est utilisé, cela vérifie que le trade-off est positif.
# Si p est INUTILISÉ (x_pc = 0 partout), cela devient Delta_p >= epsilon, ce qui est toujours VRAI.
epsilon = 0.001 

for p in pros:
    # Note: deltas[c] est négatif ici
    m.addConstr(deltas[p] + quicksum(deltas[c] * x[p, c] for c in cons) >= epsilon, name=f"Valid_{p}")

# RÉSOLUTION
m.params.outputflag = 0  
m.optimize()

# ANALYSE
print("-" * 30)
if m.status == GRB.OPTIMAL:
    print("Résultat : Une explication de type (1-m) existe !\n")
    
    # On itère sur les Pros et on vérifie s'ils ont des Cons assignés
    for p in pros:
        covered_cons = [c for c in cons if x[p, c].x > 0.5]
        
        # Si la liste n'est pas vide, c'est que ce Pro fait partie de l'explication
        if covered_cons:
            net_value = deltas[p] + sum(deltas[c] for c in covered_cons)
            print(f"Groupe mené par {p} (+{deltas[p]}) :")
            print(f"  -> Couvre : {covered_cons} (Poids cumulé Cons: {sum(deltas[c] for c in covered_cons)})")
            print(f"  -> Bilan net : +{net_value}")

elif m.status == GRB.INFEASIBLE:
    print("Résultat : INFEASIBLE (Certificat de non-existence).")
# Out:
# Arguments Pour (Pros) : ['A', 'C', 'E']
# Arguments Contre (Cons) : ['B', 'D', 'F']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).

# %% [markdown]
# # Application pour le dataset RATP

# %% [markdown]
# ## Réutilisation du code précédent

# %%
from gurobipy import *
import pandas as pd

# DONNÉES DU PROBLÈME
df_weights = pd.read_excel(
    "RATP.xlsx",
    usecols="C:I",
    skiprows=13,
    nrows=1,
) # type: ignore

# Notes des candidats u et v
data = pd.read_excel(
    "RATP.xlsx",
    usecols="B:I",
    skiprows=2,
    nrows=10,
    index_col=0,
)
df_weights.columns = data.columns
weights = df_weights.iloc[0].to_dict()

# Pour chaque paire (u,v) on effectue l'analyse précédente

for u in data.index:
    for v in data.index:
        if u == v:
            continue
        
        print(f"\n\n--- Analyse de l'explication entre {u} et {v} ---")

        # Calcul des contributions (deltas)
        deltas = {}
        for k in weights:
            deltas[k] = weights[k] * (data.loc[u, k] - data.loc[v, k])  

        pros = [k for k, v in deltas.items() if v > 0]
        cons = [k for k, v in deltas.items() if v < 0]

        print(f"Arguments Pour (Pros) : {pros}")
        print(f"Arguments Contre (Cons) : {cons}")

        # MODÉLISATION GUROBI
        m = Model("Explication_1_m")

        # Variables de décision UNIQUEMENT x
        # x[p, c] = 1 si l'argument Pro 'p' couvre l'argument Con 'c'
        x = m.addVars(pros, cons, vtype=GRB.BINARY, name="x")

        m.update()

        # CONTRAINTES

        # A. Couverture complète : Chaque Con doit être couvert par exactement un Pro
        for c in cons:
            m.addConstr(quicksum(x[p, c] for p in pros) == 1, name=f"Cover_{c}")

        # B. Validité du Trade-off
        # Formule : Delta_p + Somme(Delta_c * x_pc) >= epsilon
        # Si p est utilisé, cela vérifie que le trade-off est positif.
        # Si p est INUTILISÉ (x_pc = 0 partout), cela devient Delta_p >= epsilon, ce qui est toujours VRAI.
        epsilon = 0.001 

        for p in pros:
            # Note: deltas[c] est négatif ici
            m.addConstr(deltas[p] + quicksum(deltas[c] * x[p, c] for c in cons) >= epsilon, name=f"Valid_{p}")

        # RÉSOLUTION
        m.params.outputflag = 0  
        m.optimize()

        # ANALYSE
        print("-" * 30)
        if m.status == GRB.OPTIMAL:
            print("Résultat : Une explication de type (1-m) existe !\n")
            
            # On itère sur les Pros et on vérifie s'ils ont des Cons assignés
            for p in pros:
                covered_cons = [c for c in cons if x[p, c].x > 0.5]
                
                # Si la liste n'est pas vide, c'est que ce Pro fait partie de l'explication
                if covered_cons:
                    net_value = deltas[p] + sum(deltas[c] for c in covered_cons)
                    print(f"Groupe mené par {p} (+{deltas[p]}) :")
                    print(f"  -> Couvre : {covered_cons} (Poids cumulé Cons: {sum(deltas[c] for c in covered_cons)})")
                    print(f"  -> Bilan net : +{net_value}")

        elif m.status == GRB.INFEASIBLE:
            print("Résultat : INFEASIBLE (Certificat de non-existence).")
# Out:
# --- Analyse de l'explication entre Odéon (Ligne 4) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+85.99376545200472) :
#   -> Couvre : ['off-peak-entering-passengers/h'] (Poids cumulé Cons: -75.24454477050415)
#   -> Bilan net : +10.749220681500574
# Groupe mené par off-peak-passing-passengers/h (+96.7429861335053) :
#   -> Couvre : ['Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -94.0556809631303)
#   -> Bilan net : +2.687305170374998
# Groupe mené par strategic priority [0,10] (+128.9906481780071) :
#   -> Couvre : ['connectivity index [0,100]'] (Poids cumulé Cons: -112.86681715575621)
#   -> Bilan net : +16.123831022250883
#
#
# --- Analyse de l'explication entre Odéon (Ligne 4) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Odéon (Ligne 4) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Odéon (Ligne 4) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Odéon (Ligne 4) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Odéon (Ligne 4) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-passing-passengers/h (+225.73363431151242) :
#   -> Couvre : ['off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -171.98753090400956)
#   -> Bilan net : +53.74610340750286
# Groupe mené par strategic priority [0,10] (+128.9906481780071) :
#   -> Couvre : ['off-peak-passing-passengers/h'] (Poids cumulé Cons: -112.8668171557562)
#   -> Bilan net : +16.123831022250897
#
#
# --- Analyse de l'explication entre Odéon (Ligne 4) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+601.9563581640331) :
#   -> Couvre : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h'] (Poids cumulé Cons: -300.9781790820166)
#   -> Bilan net : +300.9781790820165
# Groupe mené par peak-passing-passengers/h (+94.05568096313017) :
#   -> Couvre : ['Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -67.18262925937869)
#   -> Bilan net : +26.873051703751486
# Groupe mené par connectivity index [0,100] (+177.36214124475975) :
#   -> Couvre : ['strategic priority [0,10]'] (Poids cumulé Cons: -112.86681715575621)
#   -> Bilan net : +64.49532408900355
#
#
# --- Analyse de l'explication entre Odéon (Ligne 4) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : []
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
#
#
# --- Analyse de l'explication entre Odéon (Ligne 4) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+279.47973771901536) :
#   -> Couvre : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h'] (Poids cumulé Cons: -196.17327743738576)
#   -> Bilan net : +83.3064602816296
# Groupe mené par connectivity index [0,100] (+161.23831022250886) :
#   -> Couvre : ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -139.73986885950782)
#   -> Bilan net : +21.498441363001035
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-passing-passengers/h (+225.73363431151242) :
#   -> Couvre : ['off-peak-entering-passengers/h'] (Poids cumulé Cons: -56.433408577878104)
#   -> Bilan net : +169.3002257336343
# Groupe mené par connectivity index [0,100] (+257.9812963560142) :
#   -> Couvre : ['off-peak-passing-passengers/h'] (Poids cumulé Cons: -209.6098032892615)
#   -> Bilan net : +48.37149306675269
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+515.9625927120284) :
#   -> Couvre : ['off-peak-passing-passengers/h', 'strategic priority [0,10]'] (Poids cumulé Cons: -451.4672686230248)
#   -> Bilan net : +64.49532408900359
# Groupe mené par connectivity index [0,100] (+290.228958400516) :
#   -> Couvre : ['off-peak-entering-passengers/h'] (Poids cumulé Cons: -112.86681715575621)
#   -> Bilan net : +177.36214124475975
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par off-peak-entering-passengers/h (+131.67795334838226) :
#   -> Couvre : ['strategic priority [0,10]'] (Poids cumulé Cons: -112.86681715575621)
#   -> Bilan net : +18.81113619262605
# Groupe mené par Station degradation level ([0,20]  scale) (+120.92873266688169) :
#   -> Couvre : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h'] (Poids cumulé Cons: -112.8668171557562)
#   -> Bilan net : +8.061915511125491
#
#
# --- Analyse de l'explication entre Place d'Italie (Lign 6) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-passing-passengers/h (+376.2227238525207) :
#   -> Couvre : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h'] (Poids cumulé Cons: -182.73675158551004)
#   -> Bilan net : +193.48597226701065
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+365.47350317102007) :
#   -> Couvre : ['strategic priority [0,10]'] (Poids cumulé Cons: -225.73363431151242)
#   -> Bilan net : +139.73986885950765
# Groupe mené par peak-passing-passengers/h (+244.54477050413846) :
#   -> Couvre : ['off-peak-entering-passengers/h'] (Poids cumulé Cons: -131.67795334838226)
#   -> Bilan net : +112.8668171557562
# Groupe mené par off-peak-passing-passengers/h (+80.61915511125441) :
#   -> Couvre : ['Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -26.87305170375138)
#   -> Bilan net : +53.746103407503035
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-passing-passengers/h (+188.11136192626034) :
#   -> Couvre : ['strategic priority [0,10]'] (Poids cumulé Cons: -96.74298613350533)
#   -> Bilan net : +91.36837579275502
# Groupe mené par off-peak-entering-passengers/h (+112.86681715575621) :
#   -> Couvre : ['connectivity index [0,100]'] (Poids cumulé Cons: -96.74298613350533)
#   -> Bilan net : +16.123831022250883
# Groupe mené par off-peak-passing-passengers/h (+241.85746533376326) :
#   -> Couvre : ['peak-entering-passengers/h'] (Poids cumulé Cons: -214.9844136300118)
#   -> Bilan net : +26.873051703751457
#
#
# --- Analyse de l'explication entre Jussieu (Ligne 7) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : []
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+64.49532408900355) :
#   -> Couvre : ['off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -56.43340857787807)
#   -> Bilan net : +8.061915511125477
# Groupe mené par off-peak-entering-passengers/h (+395.03386004514675) :
#   -> Couvre : ['peak-passing-passengers/h', 'connectivity index [0,100]'] (Poids cumulé Cons: -360.0988928302698)
#   -> Bilan net : +34.93496721487696
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par off-peak-entering-passengers/h (+112.86681715575621) :
#   -> Couvre : ['connectivity index [0,100]'] (Poids cumulé Cons: -96.74298613350533)
#   -> Bilan net : +16.123831022250883
# Groupe mené par off-peak-passing-passengers/h (+241.85746533376326) :
#   -> Couvre : ['peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -214.98441363001177)
#   -> Bilan net : +26.873051703751486
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+365.47350317102007) :
#   -> Couvre : ['strategic priority [0,10]', 'connectivity index [0,100]'] (Poids cumulé Cons: -145.11447920025796)
#   -> Bilan net : +220.3590239707621
# Groupe mené par off-peak-passing-passengers/h (+241.85746533376326) :
#   -> Couvre : ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -228.42093948188744)
#   -> Bilan net : +13.436525851875814
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par off-peak-entering-passengers/h (+300.9781790820166) :
#   -> Couvre : ['connectivity index [0,100]'] (Poids cumulé Cons: -193.48597226701065)
#   -> Bilan net : +107.49220681500594
# Groupe mené par off-peak-passing-passengers/h (+403.0957755562721) :
#   -> Couvre : ['peak-entering-passengers/h', 'peak-passing-passengers/h'] (Poids cumulé Cons: -365.47350317102007)
#   -> Bilan net : +37.62227238525202
# Groupe mené par strategic priority [0,10] (+48.37149306675266) :
#   -> Couvre : ['Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -40.309577555627186)
#   -> Bilan net : +8.061915511125477
#
#
# --- Analyse de l'explication entre Nation (Ligne 9) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par off-peak-passing-passengers/h (+306.3527894227668) :
#   -> Couvre : ['peak-entering-passengers/h'] (Poids cumulé Cons: -257.9812963560142)
#   -> Bilan net : +48.371493066752635
# Groupe mené par strategic priority [0,10] (+225.73363431151242) :
#   -> Couvre : ['Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -174.67483607438456)
#   -> Bilan net : +51.05879823712786
# Groupe mené par connectivity index [0,100] (+128.9906481780071) :
#   -> Couvre : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h'] (Poids cumulé Cons: -112.86681715575621)
#   -> Bilan net : +16.123831022250883
#
#
# --- Analyse de l'explication entre La Motte Picquet-Grenelle (Ligne 10) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par strategic priority [0,10] (+354.7242824895195) :
#   -> Couvre : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h'] (Poids cumulé Cons: -338.6004514672686)
#   -> Bilan net : +16.123831022250897
# Groupe mené par connectivity index [0,100] (+241.8574653337633) :
#   -> Couvre : ['Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -228.42093948188756)
#   -> Bilan net : +13.436525851875729
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par off-peak-passing-passengers/h (+419.219606578523) :
#   -> Couvre : ['peak-entering-passengers/h', 'peak-passing-passengers/h'] (Poids cumulé Cons: -392.3465548747716)
#   -> Bilan net : +26.8730517037514
# Groupe mené par connectivity index [0,100] (+128.9906481780071) :
#   -> Couvre : ['off-peak-entering-passengers/h'] (Poids cumulé Cons: -94.05568096313019)
#   -> Bilan net : +34.934967214876906
#
#
# --- Analyse de l'explication entre Porte d'Orléans (Ligne 4) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+472.965709986026) :
#   -> Couvre : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -456.84187896377506)
#   -> Bilan net : +16.123831022250954
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Daumenil (Ligne 6) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Vaugirard (Ligne 12) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : []
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+580.4579168010318) :
#   -> Couvre : ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]'] (Poids cumulé Cons: -534.7737289046544)
#   -> Bilan net : +45.684187896377466
# Groupe mené par connectivity index [0,100] (+128.9906481780071) :
#   -> Couvre : ['Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -94.05568096313006)
#   -> Bilan net : +34.934967214877034
#
#
# --- Analyse de l'explication entre Oberkampf (Ligne 9) et Reuilly-Diderot (Ligne 1) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et Odéon (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et Place d'Italie (Lign 6) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et Jussieu (Ligne 7) ---
# Arguments Pour (Pros) : []
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et Nation (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et La Motte Picquet-Grenelle (Ligne 10) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et Porte d'Orléans (Ligne 4) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['off-peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et Daumenil (Ligne 6) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-passing-passengers/h']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-passing-passengers/h (+338.6004514672686) :
#   -> Couvre : ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]'] (Poids cumulé Cons: -309.04009459314193)
#   -> Bilan net : +29.560356874126683
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et Vaugirard (Ligne 12) ---
# Arguments Pour (Pros) : ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'connectivity index [0,100]']
# Arguments Contre (Cons) : ['off-peak-entering-passengers/h', 'strategic priority [0,10]', 'Station degradation level ([0,20]  scale)']
# ------------------------------
# Résultat : Une explication de type (1-m) existe !
#
# Groupe mené par peak-entering-passengers/h (+322.4766204450177) :
#   -> Couvre : ['strategic priority [0,10]'] (Poids cumulé Cons: -257.9812963560142)
#   -> Bilan net : +64.49532408900353
# Groupe mené par peak-passing-passengers/h (+206.92249811888638) :
#   -> Couvre : ['off-peak-entering-passengers/h'] (Poids cumulé Cons: -169.30022573363433)
#   -> Bilan net : +37.622272385252046
# Groupe mené par off-peak-passing-passengers/h (+64.49532408900353) :
#   -> Couvre : ['Station degradation level ([0,20]  scale)'] (Poids cumulé Cons: -40.309577555627065)
#   -> Bilan net : +24.185746533376467
#
#
# --- Analyse de l'explication entre Reuilly-Diderot (Ligne 1) et Oberkampf (Ligne 9) ---
# Arguments Pour (Pros) : ['peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# Arguments Contre (Cons) : ['peak-entering-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# ------------------------------
# Résultat : INFEASIBLE (Certificat de non-existence).
